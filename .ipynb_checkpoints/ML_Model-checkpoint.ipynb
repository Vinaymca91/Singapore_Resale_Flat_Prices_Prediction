# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('combined.csv')
df

# %%
df.dtypes

# %%
df.isnull().sum()

# %% [markdown]
# ##
# Minor Data Preprocessing for Combined Data

# %%
import statistics

def get_median(x):
    try:
        split_list = x.split(' TO ')
        float_list = [float(i) for i in split_list]
        median = statistics.median(float_list)
        return median
    except ValueError:
        return None  

df['storey_median'] = df['storey_range'].apply(lambda x: get_median(x))
df
# Out:
#         latitude   longitude blk_no            road_name postal_code  \
# 0       1.375097  103.837619    174  ANG MO KIO AVENUE 4      560174
# 1       1.375097  103.837619    174  ANG MO KIO AVENUE 4      560174
# 2       1.375097  103.837619    174  ANG MO KIO AVENUE 4      560174
# 3       1.375097  103.837619    174  ANG MO KIO AVENUE 4      560174
# 4       1.375097  103.837619    174  ANG MO KIO AVENUE 4      560174
# ...          ...         ...    ...                  ...         ...
# 224486  1.444637  103.829635   118A    CANBERRA CRESCENT      751118
# 224487  1.444637  103.829635   118A    CANBERRA CRESCENT      751118
# 224488  1.444637  103.829635   118A    CANBERRA CRESCENT      751118
# 224489  1.444796  103.830160   117B    CANBERRA CRESCENT      752117
# 224490  1.444796  103.830160   117B    CANBERRA CRESCENT      752117
#
#                      address      cbd_dist  min_dist_mrt    month        town  \
# 0       174 ANG MO KIO AVE 4  10296.855747    418.541691  2015-01  ANG MO KIO
# 1       174 ANG MO KIO AVE 4  10296.855747    418.541691  2015-12  ANG MO KIO
# 2       174 ANG MO KIO AVE 4  10296.855747    418.541691  2016-05  ANG MO KIO
# 3       174 ANG MO KIO AVE 4  10296.855747    418.541691  2016-06  ANG MO KIO
# 4       174 ANG MO KIO AVE 4  10296.855747    418.541691  2016-11  ANG MO KIO
# ...                      ...           ...           ...      ...         ...
# 224486    118A CANBERRA CRES  18034.887863    172.699746  2024-07   SEMBAWANG
# 224487    118A CANBERRA CRES  18034.887863    172.699746  2024-08   SEMBAWANG
# 224488    118A CANBERRA CRES  18034.887863    172.699746  2024-08   SEMBAWANG
# 224489    117B CANBERRA CRES  18044.574080    196.770412  2024-07   SEMBAWANG
# 224490    117B CANBERRA CRES  18044.574080    196.770412  2024-07   SEMBAWANG
#
#         ... block       street_name storey_range floor_area_sqm  flat_model  \
# 0       ...   174  ANG MO KIO AVE 4     07 TO 09           60.0    Improved
# 1       ...   174  ANG MO KIO AVE 4     10 TO 12           60.0    Improved
# 2       ...   174  ANG MO KIO AVE 4     04 TO 06           69.0    Improved
# 3       ...   174  ANG MO KIO AVE 4     07 TO 09           45.0    Improved
# 4       ...   174  ANG MO KIO AVE 4     04 TO 06           61.0    Improved
# ...     ...   ...               ...          ...            ...         ...
# 224486  ...  118A     CANBERRA CRES     10 TO 12           47.0     Model A
# 224487  ...  118A     CANBERRA CRES     04 TO 06           38.0     Model A
# 224488  ...  118A     CANBERRA CRES     07 TO 09           92.0     Model A
# 224489  ...  117B     CANBERRA CRES     07 TO 09           68.0     Model A
# 224490  ...  117B     CANBERRA CRES     07 TO 09           92.0     Model A
#
#        lease_commence_date  resale_price     remaining_lease  \
# 0                     1986      255000.0                  70
# 1                     1986      275000.0                  69
# 2                     1986      310000.0                  68
# 3                     1986      253000.0                  68
# 4                     1986      290000.0                  68
# ...                    ...           ...                 ...
# 224486                2020      418000.0  94 years 11 months
# 224487                2020      330000.0  94 years 10 months
# 224488                2020      787000.0  94 years 10 months
# 224489                2020      490000.0  94 years 10 months
# 224490                2020      730000.0  94 years 11 months
#
#        lease_remain_years  storey_median
# 0                      62            8.0
# 1                      62           11.0
# 2                      62            5.0
# 3                      62            8.0
# 4                      62            5.0
# ...                   ...            ...
# 224486                 96           11.0
# 224487                 96            5.0
# 224488                 96            8.0
# 224489                 96            8.0
# 224490                 96            8.0
#
# [224491 rows x 21 columns]

# %%
scope_df = df[['cbd_dist', 'min_dist_mrt', 'floor_area_sqm', 'lease_remain_years', 'storey_median', 'resale_price']]
scope_df
# Out:
#             cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0       10296.855747    418.541691            60.0                  62
# 1       10296.855747    418.541691            60.0                  62
# 2       10296.855747    418.541691            69.0                  62
# 3       10296.855747    418.541691            45.0                  62
# 4       10296.855747    418.541691            61.0                  62
# ...              ...           ...             ...                 ...
# 224486  18034.887863    172.699746            47.0                  96
# 224487  18034.887863    172.699746            38.0                  96
# 224488  18034.887863    172.699746            92.0                  96
# 224489  18044.574080    196.770412            68.0                  96
# 224490  18044.574080    196.770412            92.0                  96
#
#         storey_median  resale_price
# 0                 8.0      255000.0
# 1                11.0      275000.0
# 2                 5.0      310000.0
# 3                 8.0      253000.0
# 4                 5.0      290000.0
# ...               ...           ...
# 224486           11.0      418000.0
# 224487            5.0      330000.0
# 224488            8.0      787000.0
# 224489            8.0      490000.0
# 224490            8.0      730000.0
#
# [224491 rows x 6 columns]

# %%
scope_df = scope_df.drop_duplicates()
scope_df
# Out:
#             cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0       10296.855747    418.541691            60.0                  62
# 1       10296.855747    418.541691            60.0                  62
# 2       10296.855747    418.541691            69.0                  62
# 3       10296.855747    418.541691            45.0                  62
# 4       10296.855747    418.541691            61.0                  62
# ...              ...           ...             ...                 ...
# 224486  18034.887863    172.699746            47.0                  96
# 224487  18034.887863    172.699746            38.0                  96
# 224488  18034.887863    172.699746            92.0                  96
# 224489  18044.574080    196.770412            68.0                  96
# 224490  18044.574080    196.770412            92.0                  96
#
#         storey_median  resale_price
# 0                 8.0      255000.0
# 1                11.0      275000.0
# 2                 5.0      310000.0
# 3                 8.0      253000.0
# 4                 5.0      290000.0
# ...               ...           ...
# 224486           11.0      418000.0
# 224487            5.0      330000.0
# 224488            8.0      787000.0
# 224489            8.0      490000.0
# 224490            8.0      730000.0
#
# [217709 rows x 6 columns]

# %% [markdown]
# # Checking and Handling for Skewness in the Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns(continuous variables) for finding skewness
col = ['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']

for i in col:
    plt.figure(figsize=(8, 6))  
    sns.boxplot(data=df, x=i)
    plt.title(f'Boxplot of {i}')
    plt.xlabel(i)
    plt.show()

# %%
df1 = scope_df

# %%
# Apply log transformation to reduce skewness
df1['floor_area_sqm'] = np.log(df1['floor_area_sqm'])
sns.boxplot(x='floor_area_sqm', data=df1)
plt.show()

df1['storey_median'] = np.log(df1['storey_median'])
sns.boxplot(x='storey_median', data=df1)
plt.show()

df1['resale_price'] = np.log(df1['resale_price'])
sns.boxplot(x='resale_price', data=df1)
plt.show()

# %%
df1.dtypes
# Out:
# cbd_dist              float64
# min_dist_mrt          float64
# floor_area_sqm        float64
# lease_remain_years      int64
# storey_median         float64
# resale_price          float64
# dtype: object

# %% [markdown]
# # Visualization among different columns using Correlation Matrix

# %%
import seaborn as sns

corrMatrix = df1.corr()
plt.figure(figsize=(15, 10))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
plt.show()

# %% [markdown]
# # Encoding Data

# %%
from sklearn.preprocessing import StandardScaler

# Select features and target variable
X = df1[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median']]
y = df1['resale_price']

# Standardize the features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
test_dataframe = pd.DataFrame(X)
test_dataframe
# Out:
#                0         1         2         3         4
# 0      -0.490827 -0.812672 -1.761289 -0.678425  0.211788
# 1      -0.490827 -0.812672 -1.761289 -0.678425  0.654969
# 2      -0.490827 -0.812672 -1.217193 -0.678425 -0.442298
# 3      -0.490827 -0.812672 -2.881240 -0.678425  0.211788
# 4      -0.490827 -0.812672 -1.696940 -0.678425 -0.442298
# ...          ...       ...       ...       ...       ...
# 217704  1.268770 -1.383998 -2.711952  1.808354  0.654969
# 217705  1.268770 -1.383998 -3.539458  1.808354 -0.442298
# 217706  1.268770 -1.383998 -0.097242  1.808354  0.211788
# 217707  1.270972 -1.328059 -1.274027  1.808354  0.211788
# 217708  1.270972 -1.328059 -0.097242  1.808354  0.211788
#
# [217709 rows x 5 columns]

# %% [markdown]
# # Splitting the Data for Training and Testing Purposes

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV

# Decision Tree Regressor
dtr = DecisionTreeRegressor()

# hyperparameters
param_grid = {
    'max_depth': [2, 5, 10, 15, 20, 22],
    'min_samples_split': [2, 3, 4, 5],
    'min_samples_leaf': [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20],
    'max_features': ['auto', 'sqrt', 'log2']
}

# gridsearchcv
grid_search = GridSearchCV(estimator=dtr, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
print("Best hyperparameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# evalution metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print(" ")
print('Mean squared error:', mse)
print('Mean Absolute Error', mae)
print('Root Mean squared error:', rmse)
print(" ")
print('R-squared:', r2)
